# %% [markdown]
# ###A quick test to veify if Python is working here:

# %%
print("Hello, world")
# Out:
# Hello, world

# %% [markdown]
# ###Mount "IT166" folder from your Google drive to Colab. You can use the similar code to mount any folder/subfolder accordingly.

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir("/content/drive/My Drive/IT166/")
